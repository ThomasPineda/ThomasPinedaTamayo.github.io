# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasPineda/ThomasPinedaTamayo.github.io/blob/main/GEA_PINEDAthomas_IO1_Prueba_Thomas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ##Preselección tutores GEA IO 1 | 2023-1 - Thomas Pineda Tamayo
#
#
# **Minimizar** 3*x + 8*y
#
# **sujeto a:**
#
# 1.  x + y >= 50
# 2.  2
# x - y <= 20
# 3.  x >= 0
# 4.  y >= 0

# %%
#Import Library
import cvxpy as cp

# %%
#Create the variables 
x = cp.Variable() ; y = cp.Variable()

#Create Objetive Function 
obj = cp.Minimize(3*x + 8*y)

#Create the restrictions
suj = [x + y >= 50, 2*x - y <= 20, x >= 0, y >= 0]

#Create the problem
prom = cp.Problem(obj, suj)

# %%
#Solve 
s = prom.solve()
print("\nThe optimal value is", prom.value)
print("With X_opt = %f, y_opt = %f" %(x.value, y.value))
print("The dual price of X is",prom.constraints[0].dual_value)
print("The dual price of y is",prom.constraints[1].dual_value)

# %%
s = prom.solve(solver=cp.OSQP)
d = prom.solve(solver=cp.ECOS)
c = d - s 
print("la diferencia entre CP.OSQP y CP.ECOS es de: ", c)

# %%
# Solve with OSQP.
prom.solve(solver=cp.OSQP)
print("\noptimal value with OSQP:", prom.value)
print("With X_opt = %f, y_opt = %f" %(x.value, y.value))
print("The dual price of X is",prom.constraints[0].dual_value)
print("The dual price of y is",prom.constraints[1].dual_value)

# Solve with ECOS.
prom.solve(solver=cp.ECOS)
print("\noptimal value with ECOS:", prom.value)
print("With X_opt = %f, y_opt = %f" %(x.value, y.value))
print("The dual price of X is",prom.constraints[0].dual_value)
print("The dual price of y is",prom.constraints[1].dual_value)

# Solve with CVXOPT.
prom.solve(solver=cp.CVXOPT)
print("\noptimal value with CVXOPT:", prom.value)
print("With X_opt = %f, y_opt = %f" %(x.value, y.value))
print("The dual price of X is",prom.constraints[0].dual_value)
print("The dual price of y is",prom.constraints[1].dual_value)

# Solve with SCS.
prom.solve(solver=cp.SCS)
print("\noptimal value with SCS:", prom.value)
print("With X_opt = %f, y_opt = %f" %(x.value, y.value))
print("The dual price of X is",prom.constraints[0].dual_value)
print("The dual price of y is",prom.constraints[1].dual_value)

# %%
s = 224.99999968160370.

# %% [markdown]
# ##Comparación.
# Todas las soluciones que arrojan los diferentes Solver son muy similares y cercanas, esto se debe a que el problema no tiene un grado alto de complejidad y la función objetivo es de carácter líneal haciendo que todos los solver lleguen a una respuesta muy cercanas entre sí. Las pequeñas diferencias que hay entre respuestas se pueden deber a como los diferentes algoritmos de optimización operen en el problema para llegar a una solución.
